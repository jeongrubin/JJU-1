# %%
pip install -q praisonaiagents
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 3.1 MB/s eta 0:00:00

# %%
# !pip install -qU duckduckgo_search
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 34.0 MB/s eta 0:00:00

# %%
import os
os.environ["OPENAI_API_KEY"] = ""

# %%
from praisonaiagents import Agent, Agents, Tools

# user_input = input("검색할 질문을 입력하세요: ")

# 사용자로부터 영어로 질문 입력받기
user_input = input("Enter your question in English: ")

# 리서치 에이전트 정의
research_agent = Agent(
    instructions=f"You are a research agent tasked to search the internet about the question: '{user_input}'. You must show the search process and respond in Korean.",
    tools=[Tools.internet_search],
    # lim='gpt-4o',
)

# 요약 에이전트 정의
summarize_agent = Agent(
    instructions="You are a summarize agent. Your task is to summarize the research agent's findings and provide the summary in Korean.",
    # lim='gpt-4o',
)

agents = Agents(agents=[research_agent, summarize_agent])
agents.start()
# Out:
# Enter your question in English: Recently, on artificial intelligence
# ╭────────────────────────────────────────────────── Instruction ──────────────────────────────────────────────────╮
# │ Agent Agent is processing prompt:                                                                               │
# │ You need to do the following task: You are a research agent tasked to search the internet about the question:   │
# │ 'Recently, on artificial intelligence'. You must show the search process and respond in Korean..                │
# │ Expected Output: Complete the assigned task successfully.                                                       │
# │ Please provide only the final result of your work. Do not add any conversation or extra explanation.            │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────── Tool Call ───────────────────────────────────────────────────╮
# │ Agent Agent is calling function 'internet_search' with arguments: {'query': 'Recently, on artificial            │
# │ intelligence'}                                                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────── Tool Call ───────────────────────────────────────────────────╮
# │ Function 'internet_search' returned: [{"title": "Artificial Intelligence - Latest AI News and Analysis -        │
# │ WSJ.com", "url": "https://www.wsj.com/tech/ai", "snippet": "The latest artificial intelligence news coverage    │
# │ focusing on the technology, tools and the companies building AI technology. Read Artificial Intelligence on The │
# │ Wall Street Journal."}, {"title": "Entering The Artificial General Intelligence Spectrum In 2025 - Forbes",     │
# │ "url":                                                                                                          │
# │ "https://www.forbes.com/sites/craigsmith/2025/01/07/entering-the-artificial-general-intelligence-spectrum-in-20 │
# │ 25/", "snippet": "Neural network of the brain on a dark blue background. getty From Narrow Intelligence to      │
# │ General Capability. Until now, AI systems have excelled as specialists\u2014writing copy, diagnosing diseases   │
# │ ..."}, {"title": "Artificial intelligence | MIT News | Massachusetts Institute of Technology", "url":           │
# │ "https://news.mit.edu/topic/artificial-intelligence2", "snippet": "Artificial intelligence. Download RSS feed:  │
# │ News Articles / In the Media / Audio. Displaying 1 - 15 of 1286 news articles related to this topic. Show: News │
# │ Articles. In the Media. Audio. A new computational model can predict antibody structures more accurately. Using │
# │ this model, researchers may be able to identify antibody drugs that can target ..."}, {"title": "The current    │
# │ state of AI, according to Stanford's AI Index | World ...", "url":                                              │
# │ "https://www.weforum.org/stories/2024/04/stanford-university-ai-index-report/", "snippet": "Artificial          │
# │ intelligence's (AI) influence on society has never been more pronounced. Since ChatGPT became a ubiquitous      │
# │ feature on computer desktops in late 2022, the rapid development and deployment of generative AI and large      │
# │ language model (LLM) tools have started to transform industries and show the potential to touch many aspects of │
# │ modern life."}, {"title": "Artificial Intelligence - The New York Times", "url":                                │
# │ "https://www.nytimes.com/spotlight/artificial-intelligence", "snippet": "The artificial intelligence start-up   │
# │ argues that Mr. Musk is trying to hamstring its business as he builds a rival company. By Cade Metz and Ryan    │
# │ Mac Credit Jeenah Moon for The New York Times"}]                                                                │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Response generated in 11.4s
# ╭──────────────────────────────────────────────────── Message ────────────────────────────────────────────────────╮
# │ You need to do the following task: You are a research agent tasked to search the internet about the question:   │
# │ 'Recently, on artificial intelligence'. You must show the search process and respond in Korean.. Expected       │
# │ Output: Complete the assigned task successfully. Please provide only the final result of your work. Do not add  │
# │ any conversation or extra explanation.                                                                          │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────── Response ────────────────────────────────────────────────────╮
# │ 최근 인공지능에 관한 뉴스는 다음과 같습니다:                                                                    │
# │                                                                                                                 │
# │  1 월스트리트저널: 인공지능 기술과 관련된 최신 뉴스와 분석을 제공하고 있습니다. ]8;id=416880;https://www.wsj.com/tech/ai\링크]8;;\                            │
# │  2 포브스: 2025년 인공지능의 일반 지능 스펙트럼에 진입하는 것에 대한 기사. ]8;id=813942;https://www.forbes.com/sites/craigsmith/2025/01/07/entering-the-artificial-general-intelligence-spectrum-in-2025/\링크]8;;\                                 │
# │  3 MIT 뉴스: 인공지능 관련 연구와 미디어 기사를 다루고 있으며, 최근에는 항체 구조를 더 정확하게 예측할 수 있는  │
# │    새로운 계산 모델에 대해 보도하였습니다. ]8;id=332761;https://news.mit.edu/topic/artificial-intelligence2\링크]8;;\                                                                 │
# │  4 세계경제포럼: 스탠포드 대학의 AI 인덱스 보고서에 따르면, 인공지능의 사회적 영향이 점점 커지고 있으며, 특히   │
# │    ChatGPT와 같은 생성 AI 및 대규모 언어 모델 도구의 발전이 산업을 변화시키고 있습니다. ]8;id=328170;https://www.weforum.org/stories/2024/04/stanford-university-ai-index-report/\링크]8;;\                    │
# │  5 뉴욕타임스: 인공지능 스타트업과 관련된 다양한 뉴스와 분석을 제공하고 있습니다. ]8;id=451568;https://www.nytimes.com/spotlight/artificial-intelligence\링크]8;;\                          │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Instruction ──────────────────────────────────────────────────╮
# │ Agent Agent is processing prompt:                                                                               │
# │ You need to do the following task: You are a summarize agent. Your task is to summarize the research agent's    │
# │ findings and provide the summary in Korean..                                                                    │
# │ Expected Output: Complete the assigned task successfully.                                                       │
# │                                                                                                                 │
# │ Here are the results of previous tasks that might be useful:                                                    │
# │                                                                                                                 │
# │ Result of previous task Agent: 최근 인공지능에 관한 뉴스는 다음과 같습니다:                                     │
# │                                                                                                                 │
# │ 1. **월스트리트저널**: 인공지능 기술과 관련된 최신 뉴스와 분석을 제공하고 있습니다.                             │
# │ [링크](https://www.wsj.com/tech/ai)                                                                             │
# │                                                                                                                 │
# │ 2. **포브스**: 2025년 인공지능의 일반 지능 스펙트럼에 진입하는 것에 대한 기사.                                  │
# │ [링크](https://www.forbes.com/sites/craigsmith/2025/01/07/entering-the-artificial-general-intelligence-spectrum │
# │ -in-2025/)                                                                                                      │
# │                                                                                                                 │
# │ 3. **MIT 뉴스**: 인공지능 관련 연구와 미디어 기사를 다루고 있으며, 최근에는 항체 구조를 더 정확하게 예측할 수   │
# │ 있는 새로운 계산 모델에 대해 보도하였습니다. [링크](https://news.mit.edu/topic/artificial-intelligence2)        │
# │                                                                                                                 │
# │ 4. **세계경제포럼**: 스탠포드 대학의 AI 인덱스 보고서에 따르면, 인공지능의 사회적 영향이 점점 커지고 있으며,    │
# │ 특히 ChatGPT와 같은 생성 AI 및 대규모 언어 모델 도구의 발전이 산업을 변화시키고 있습니다.                       │
# │ [링크](https://www.weforum.org/stories/2024/04/stanford-university-ai-index-report/)                            │
# │                                                                                                                 │
# │ 5. **뉴욕타임스**: 인공지능 스타트업과 관련된 다양한 뉴스와 분석을 제공하고 있습니다.                           │
# │ [링크](https://www.nytimes.com/spotlight/artificial-intelligence)                                               │
# │                                                                                                                 │
# │ Please provide only the final result of your work. Do not add any conversation or extra explanation.            │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Response generated in 13.3s
# ╭──────────────────────────────────────────────────── Message ────────────────────────────────────────────────────╮
# │ You need to do the following task: You are a summarize agent. Your task is to summarize the research agent's    │
# │ findings and provide the summary in Korean.. Expected Output: Complete the assigned task successfully.          │
# │                                                                                                                 │
# │ Here are the results of previous tasks that might be useful:                                                    │
# │                                                                                                                 │
# │ Result of previous task Agent: 최근 인공지능에 관한 뉴스는 다음과 같습니다:                                     │
# │                                                                                                                 │
# │  1 월스트리트저널: 인공지능 기술과 관련된 최신 뉴스와 분석을 제공하고 있습니다. ]8;id=473172;https://www.wsj.com/tech/ai\링크]8;;\                            │
# │  2 포브스: 2025년 인공지능의 일반 지능 스펙트럼에 진입하는 것에 대한 기사. ]8;id=735867;https://www.forbes.com/sites/craigsmith/2025/01/07/entering-the-artificial-general-intelligence-spectrum-in-2025/\링크]8;;\                                 │
# │  3 MIT 뉴스: 인공지능 관련 연구와 미디어 기사를 다루고 있으며, 최근에는 항체 구조를 더 정확하게 예측할 수 있는  │
# │    새로운 계산 모델에 대해 보도하였습니다. ]8;id=49644;https://news.mit.edu/topic/artificial-intelligence2\링크]8;;\                                                                 │
# │  4 세계경제포럼: 스탠포드 대학의 AI 인덱스 보고서에 따르면, 인공지능의 사회적 영향이 점점 커지고 있으며, 특히   │
# │    ChatGPT와 같은 생성 AI 및 대규모 언어 모델 도구의 발전이 산업을 변화시키고 있습니다. ]8;id=5151;https://www.weforum.org/stories/2024/04/stanford-university-ai-index-report/\링크]8;;\                    │
# │  5 뉴욕타임스: 인공지능 스타트업과 관련된 다양한 뉴스와 분석을 제공하고 있습니다. ]8;id=362869;https://www.nytimes.com/spotlight/artificial-intelligence\링크]8;;\                          │
# │                                                                                                                 │
# │ Please provide only the final result of your work. Do not add any conversation or extra explanation.            │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────── Response ────────────────────────────────────────────────────╮
# │ 최근 인공지능에 관한 연구 결과는 다음과 같습니다:                                                               │
# │                                                                                                                 │
# │  1 월스트리트저널은 인공지능 기술과 관련된 최신 뉴스와 분석을 제공하고 있습니다.                                │
# │  2 포브스는 2025년 인공지능의 일반 지능 스펙트럼에 진입하는 것에 대한 기사를 다루고 있습니다.                   │
# │  3 MIT 뉴스는 항체 구조를 더 정확하게 예측할 수 있는 새로운 계산 모델에 대해 보도하였습니다.                    │
# │  4 세계경제포럼은 스탠포드 대학의 AI 인덱스 보고서를 통해 인공지능의 사회적 영향이 커지고 있으며, 특히          │
# │    ChatGPT와 같은 생성 AI 및 대규모 언어 모델 도구의 발전이 산업을 변화시키고 있다고 보고합니다.                │
# │  5 뉴욕타임스는 인공지능 스타트업과 관련된 다양한 뉴스와 분석을 제공하고 있습니다.                              │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# {'task_status': {0: 'completed', 1: 'completed'},
#  'task_results': {0: TaskOutput(description="You are a research agent tasked to search the internet about the question: 'Recently, on artificial intelligence'. You must show the search process and respond in Korean.", summary='You are a ', raw='최근 인공지능에 관한 뉴스는 다음과 같습니다:\n\n1. **월스트리트저널**: 인공지능 기술과 관련된 최신 뉴스와 분석을 제공하고 있습니다. [링크](https://www.wsj.com/tech/ai)\n\n2. **포브스**: 2025년 인공지능의 일반 지능 스펙트럼에 진입하는 것에 대한 기사. [링크](https://www.forbes.com/sites/craigsmith/2025/01/07/entering-the-artificial-general-intelligence-spectrum-in-2025/)\n\n3. **MIT 뉴스**: 인공지능 관련 연구와 미디어 기사를 다루고 있으며, 최근에는 항체 구조를 더 정확하게 예측할 수 있는 새로운 계산 모델에 대해 보도하였습니다. [링크](https://news.mit.edu/topic/artificial-intelligence2)\n\n4. **세계경제포럼**: 스탠포드 대학의 AI 인덱스 보고서에 따르면, 인공지능의 사회적 영향이 점점 커지고 있으며, 특히 ChatGPT와 같은 생성 AI 및 대규모 언어 모델 도구의 발전이 산업을 변화시키고 있습니다. [링크](https://www.weforum.org/stories/2024/04/stanford-university-ai-index-report/)\n\n5. **뉴욕타임스**: 인공지능 스타트업과 관련된 다양한 뉴스와 분석을 제공하고 있습니다. [링크](https://www.nytimes.com/spotlight/artificial-intelligence)', pydantic=None, json_dict=None, agent='Agent', output_format='RAW'),
#   1: TaskOutput(description="You are a summarize agent. Your task is to summarize the research agent's findings and provide the summary in Korean.", summary='You are a ', raw='최근 인공지능에 관한 연구 결과는 다음과 같습니다:\n\n1. 월스트리트저널은 인공지능 기술과 관련된 최신 뉴스와 분석을 제공하고 있습니다.\n2. 포브스는 2025년 인공지능의 일반 지능 스펙트럼에 진입하는 것에 대한 기사를 다루고 있습니다.\n3. MIT 뉴스는 항체 구조를 더 정확하게 예측할 수 있는 새로운 계산 모델에 대해 보도하였습니다.\n4. 세계경제포럼은 스탠포드 대학의 AI 인덱스 보고서를 통해 인공지능의 사회적 영향이 커지고 있으며, 특히 ChatGPT와 같은 생성 AI 및 대규모 언어 모델 도구의 발전이 산업을 변화시키고 있다고 보고합니다.\n5. 뉴욕타임스는 인공지능 스타트업과 관련된 다양한 뉴스와 분석을 제공하고 있습니다.', pydantic=None, json_dict=None, agent='Agent', output_format='RAW')}}
