# %% [markdown]
# # Microsoft Word

# %% [markdown]
# [Microsoft Word](https://www.microsoft.com/en-us/microsoft-365/word)는 Microsoft에서 개발한 워드 프로세서입니다.
#
# 이는 `Word` 문서를 하류에서 사용할 수 있는 문서 형식으로 로드하는 방법을 다룹니다.

# %% [markdown]
# ## Docx2txtLoader
#
# `Docx2txt`를 사용하여 .docx 파일을 문서로 불러올 수 있습니다.

# %%
# 설치
# !pip install -qU docx2txt

# %%
# !pip install -qU langchain-community

# %%
from langchain_community.document_loaders import Docx2txtLoader

loader = Docx2txtLoader("/content/sample-word-document.docx")  # 문서 로더 초기화

docs = loader.load()  # 문서 로딩

print(len(docs))
# Out:
# 1

# %%
docs[0].page_content
docs[0].metadata
# Out:
# {'source': '/content/sample-word-document.docx'}

# %% [markdown]
# ## UnstructuredWordDocumentLoader
