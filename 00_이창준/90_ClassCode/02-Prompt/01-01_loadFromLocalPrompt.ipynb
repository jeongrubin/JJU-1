# %% [markdown]
# ## 1. yaml 화일 사용
# Jun---
# - yaml 화일 살펴보기
#  - fruit_color로 기본 구조 보기
#  - capital로 복잡한 구조 보기
#  - 원래 한줄작성이 원칙
#  - |를 사용하여 여러줄 사용가능
#  - 들여쓰기 사용법

# %%
# !pip install -qU langchain langchain_core langchain_teddynote
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.7/34.7 MB 40.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.6/411.6 kB 11.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 32.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.7/135.7 kB 8.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 2.6 MB/s eta 0:00:00
# ...

# %%
from langchain_core.prompts import load_prompt

prompt = load_prompt("/content/fruit_color.yaml", encoding="utf-8")
prompt
# Out:
# PromptTemplate(input_variables=['fruit'], input_types={}, partial_variables={}, template='{fruit}의 색깔이 뭐야?')

# %% [markdown]
# Jun---
# 윈도우에서 에러가 나는 경우 'cp949'로 인코딩 변경

# %%
from langchain_teddynote.prompts import load_prompt

# Windows 사용자 only: 인코딩을 cp949로 설정
load_prompt("/content/fruit_color.yaml", encoding="cp949")
# Out:
# PromptTemplate(input_variables=['fruit'], input_types={}, partial_variables={}, template='{fruit}의 색깔이 뭐야?')

# %%
prompt.format(fruit="사과")
# Out:
# '사과의 색깔이 뭐야?'

# %%
prompt2 = load_prompt("/content/capital.yaml")
print(prompt2.format(country="대한민국"))
# Out:
# 대한민국의 수도에 대해서 알려주세요.
# 수도의 특징을 다음의 양식에 맞게 정리해 주세요.
# 300자 내외로 작성해 주세요.
# 한글로 작성해 주세요.
# ----
# [양식]
# 1. 면적
# 2. 인구
# 3. 역사적 장소
# 4. 특산품
#
# #Answer:

# %%
# !pip install -qU langchain_openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 2.7 MB/s eta 0:00:00

# %%
from langchain_openai import ChatOpenAI

OPENAI_API_KEY='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'
chain = prompt2|ChatOpenAI(api_key=OPENAI_API_KEY, model_name="gpt-4o", temperature=0)
response=chain.invoke({"country": "대한민국"})

# %%
response.content
# Out:
# '1. 면적: 대한민국의 수도인 서울특별시는 약 605.21㎢의 면적을 가지고 있습니다. 이는 전국에서 가장 큰 도시 중 하나로, 다양한 문화와 경제 활동이 이루어지는 중심지입니다.  \n2. 인구: 서울의 인구는 약 950만 명으로, 대한민국에서 가장 인구가 많은 도시입니다. 다양한 인종과 문화가 공존하며, 국제적인 도시로서의 면모를 갖추고 있습니다.  \n3. 역사적 장소: 서울에는 경복궁, 창덕궁, 덕수궁 등 조선시대의 궁궐들이 있으며, 한양도성, 종묘 등 유네스코 세계문화유산으로 지정된 역사적 장소들이 많습니다. 이러한 장소들은 서울의 오랜 역사와 문화를 엿볼 수 있는 중요한 유적지입니다.  \n4. 특산품: 서울은 전통과 현대가 조화를 이루는 도시로, 한복, 한지, 전통주 등이 특산품으로 꼽힙니다. 또한, 다양한 현대 패션과 기술 제품들도 서울을 대표하는 상품으로 인기를 끌고 있습니다.'

# %% [markdown]
# Jun---
# - vscode로 가져가서 test.txt에 붙여놓고 봅시다.
# - chatGPT에게 동일하게 물어보자.
# ---
# 질문에 대답해 줘.
#
# ### Template
# template: |
#   {country}의 수도에 대해서 알려주세요.
#   수도의 특징을 다음의 양식에 맞게 정리해 주세요.
#   300자 내외로 작성해 주세요.
#   한글로 작성해 주세요.
#   ----
#   [양식]
#   1. 면적
#   2. 인구
#   3. 역사적 장소
#   4. 특산품
#
#   #Answer:
#
# ### Input
# {'country':'코트디부아르'}
#
# ---
